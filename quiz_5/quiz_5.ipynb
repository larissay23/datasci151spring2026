# %% [markdown]
# # <span style="color:red; font-size:25px"> DATASCI 151 - Quiz #5 </span>

# %% [markdown]
# <font size = "4" >
# This quiz is open book
#
# <br>
#
# - You <span style="color:red"> CAN </span> use all material from the course repo
#
# - You should <span style="color:red"> NOT </span> use other resources outside the course repo.
#
# - You should <span style="color:red"> NOT </span> collaborate with other students
#
# <!-- - This is a graded quiz. Use of LLMs or any AI tools is <span style="color:red"> NOT ALLOWED. </span> -->
#
# - AI assistance is <span style="color:red"> NOT </span> permitted for this assignment.
#
# - To get full credit, the code should work as intended. But try to attempt every problem - you can still receive partial credit.
#
# <br>
#
# Print the following string:
#
# "I will abide by Emory's code of conduct"

# %%
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "4">
#
# Import any packages you would like in the cell below. Or, import them as needed later in the notebook.

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "4">
#
# **Q1** Recode a numeric column
#
# <font size = "3">
#
# - Read in the file "movies.csv" from the `quiz_data` folder, saving it as a DataFrame.
#
# - Recode the "year" variable to create a new variable called "time_period" with the following categories. (**Both** endpoints are included in the listed categories)
#
#     - **Silent Era**: Films made between 1917 and 1927
#
#     - **Golden Age**: Films made between 1928 and 1949
#
#     - **Post-War**: Films made between 1950 and 1964
#
#     - **New Hollywood**: Films made between 1965 and 1974
#
#     - **Blockbuster Era**: Movies made between 1975 and 2000
#
#     - **Digital Age**: Movies made between 2001 until the present
#
# - You must use the `pd.cut` function to recode this variable.
#
# - Add a new column to the DataFrame called "Era" that contains this recoded variable.

# %%
# your code here
df_movies =  pd.read_csv("quiz_data/movies.csv")
#display(df_movies)

bins = [1916, 1927, 1949, 1964, 1974, 2000, np.inf]
labels = ["Silent Era", "Golden Age", "Post-War", "New Hollywood", "Blockbuster Era", "Digital Age"]

df_movies["time_period"] = pd.cut(x = df_movies["Year"], bins = bins, labels = labels)
display(df_movies.sort_values(by = "Year"))
# Out:
#                                               Title  IMDb rating  Year  \
# 3835                                            She          6.9  1917
# 1090  Homunculus, 6. Teil - Das Ende des Homunculus          6.7  1917
# 1456                              A léleklátó sugár          5.3  1918
# 67                                          The Kid          8.2  1921
# 2067                   The City Struck by Lightning          5.7  1924
# ...                                             ...          ...   ...
# 342                    Harold and the Purple Crayon          7.1  2024
# 3110                             Orion and the Dark          6.3  2024
# 1491                                    Under Paris          6.9  2024
# 1247                                      Minecraft          7.1  2025
# 2115                                          Blade          6.9  2025
#
#      MPA rating      Genre         Director  \
# 3835          R      Drama      Kenean Buel
# 1090          R      Drama     Otto Rippert
# 1456          R     Sci-Fi     Alfréd Deésy
# 67        Other     Comedy  Charles Chaplin
# 2067          R     Sci-Fi      Luitz-Morat
# ...         ...        ...              ...
# 342          PG  Animation  Carlos Saldanha
# 3110      Other  Animation    Sean Charmatz
# 1491          R     Action      Xavier Gens
# 1247          R     Action       Jared Hess
# 2115          R     Action     Yann Demange
#
#                                        Star Cast  MetaScore  \
# 3835      Valeska SurattBen TaggartMiriam Fouche       66.0
# 1090  Olaf FønssFriedrich KühneMechthildis Thein       66.0
# 1456     Daniel RadcliffeEmma WatsonRupert Grint       66.0
# 67                               Charles Chaplin       57.1
# 2067  Daniel MendailleJane MaguenatArmand Morins       66.0
# ...                                          ...        ...
# 342   Zachary LeviLil Rel HoweryBenjamin Bottani       66.9
# 3110                              Jacob Tremblay       72.0
# 1491   Sebastien AuscherYannick DahanXavier Gens       66.0
# 1247  Chris BowmanHubbel PalmerAllison Schroeder       66.9
# 2115   Gene ColanMichael GreenStacy Osei-Kuffour       66.0
#
#       Duration (minutes)  time_period
# 3835               116.3   Silent Era
# 1090               116.3   Silent Era
# 1456               116.3   Silent Era
# 67                  68.0   Silent Era
# 2067               116.3   Silent Era
# ...                  ...          ...
# 342                 92.0  Digital Age
# 3110                93.0  Digital Age
# 1491               116.3  Digital Age
# 1247               116.3  Digital Age
# 2115               116.3  Digital Age
#
# [3895 rows x 10 columns]

# %% [markdown]
# <font size = "4">
#
# **Q2** Conditional Subsetting
#
# <font size = "3">
#
# - Continue to use the movies DataFrame from Q1 (or read it in again)
#
# - Return a DataFrame with the **6 shortest movies** that (a) were released 2011 or later, and (b) have IMDb rating of 6.0 or greater.
#
# **Hint**: The column containing the IMDb rating is named "IMDb rating", which would not be a valid Python variable because of the space. If this causes you trouble and you don't remember how to handle it, you could simply rename the column to "IMDb_rating".

# %%
# your code here
df_movies =  pd.read_csv("quiz_data/movies.csv")

shortest_movies = (df_movies.query("(Year >= 2011) and (`IMDb rating` >= 6.0)")
                   .sort_values(by = "Duration (minutes)", ascending = True)
                   .iloc[:6,:])
display(shortest_movies)
#print(type(shortest_movies))
# Out:
#                            Title  IMDb rating  Year MPA rating        Genre  \
# 784             Words of Everest          7.4  2013         PG  Documentary
# 3857                  TED Rising          6.6  2016      PG-13       Action
# 621       Projections of America          8.0  2014         PG  Documentary
# 1739  Hawaii the Stolen Paradise          6.3  2014      PG-13  Documentary
# 280     9/11 Inside the Pentagon          7.0  2016         PG  Documentary
# 1657          Voices from Within          6.4  2014      PG-13  Documentary
#
#             Director                                          Star Cast  \
# 784    Paul Copeland  Stephen Campbell MooreJon Edgley-BondJason Fle...
# 3857    Bartu Atabek                 Onat YigitMert SayarNevzat Özdemir
# 621     Peter Miller               John LithgowVictoria RiskinIan Scott
# 1739     Luis Castro            Daniel RadcliffeEmma WatsonRupert Grint
# 280   Sharon Petzold            Daniel RadcliffeEmma WatsonRupert Grint
# 1657      Joy Haynes                Lewis EckerKevin McCainJames Snyder
#
#       MetaScore  Duration (minutes)
# 784        66.0                46.0
# 3857       66.0                50.0
# 621        66.0                52.0
# 1739       66.0                53.0
# 280        66.0                54.0
# 1657       66.0                54.0

# %% [markdown]
# <font size = "4">
#
# **Q3** Aggregating Group Statistics with Chaining
#
# <font size = "3">
#
# - Continue to use the movies DataFrame from Q1 (or read it in again)
#
# - The column "MPA rating" shows whether the movie was rated R, PG-13, etc. Aggregate the following statistics for each MPA rating:
#
#     - Mean IMDb rating
#
#     - Median duration (in minutes)
#
# - Sort the resulting DataFrame by mean IMDb rating in **ascending** order.
#
# - For full credit, execute all commands on a single line by chaining

# %%
# your code here
df_movies =  pd.read_csv("quiz_data/movies.csv")

(df_movies.groupby("MPA rating") 
 .agg(mean_IMDb_rating = ("IMDb rating", "mean"), median_duration_min = ("Duration (minutes)", "median")) 
 .sort_values(by = "mean_IMDb_rating", ascending = True))
# Out:
#             mean_IMDb_rating  median_duration_min
# MPA rating
# X                   6.100000                 90.0
# NC-17               6.544444                105.0
# PG                  6.613674                100.0
# Other               6.671545                 98.0
# Not Rated           6.696748                 93.0
# R                   6.795246                116.3
# PG-13               6.956572                116.0
# G                   6.999614                 93.0

# %% [markdown]
# <font size = "4">
#
# **Q4** Calculate laps per minute
#
# <font size = "3">
#
# - Read in the file "results_cleaned.csv" from the `quiz_data` folder, saving it as a DataFrame.
#
# - The "milliseconds" column shows the race duration for each result measured in milliseconds. Create a new column called "race_duration_minutes" where we convert the race duration to minutes by dividing each millisecond value by 60,000 (which equals $6 \times 10^4$). Equivalently, you can multiply each millisecond value by $6 \times 10^{-4}$
#
# - Create a new column called "laps_per_minute" which is calculated by the formula: $\ \dfrac{\textrm{laps}}{\textrm{race\_duration\_minutes}}$
#
# - Group the data by **both** "raceId" and "driverId" and calculate the **maximum laps per minutes** for each group.
#
# - Sort the data in descending order and then extract the raceId/driverId pairs with the 5 highest laps per minute
#
# <br>
#
# **Hint**: For a Pandas Series, the `.sort_values()` method does **not** take the keyword "by".

# %%
# your code here
df_results =  pd.read_csv("quiz_data/results_cleaned.csv")
#display(df_results)

df_results["race_duration_minutes"] = df_results["milliseconds"] / 6e4
df_results["laps_per_minute"] = df_results["laps"] / df_results["race_duration_minutes"]

gb = df_results.groupby(["raceId", "driverId"])
gb["laps_per_minute"].max().sort_values(ascending = False).head(5)
# Out:
# raceId  driverId
# 653     235         1.106920
#         223         1.103572
#         278         1.093937
# 598     238         0.976598
#         182         0.972569
# Name: laps_per_minute, dtype: float64

# %% [markdown]
# <font size = "4">
#
# **Q5** Aggregate and query
#
# <font size = "3">
#
# - Continue to use the "results_cleaned.csv" DataFrame from Q4 (or read it in again)
#
# - Do the following in a single line using chaining:
#
#     - Extract the subset with raceId equal to 21.
#
#     - Aggregate the minimum number of points and average number of points for each constructor in the subset.
#
#     - Extract the subset of these constructors with average number of points **strictly greater than 1**

# %%
# your code here
df_results =  pd.read_csv("quiz_data/results_cleaned.csv")
#display(df_results)
(df_results.query("raceId == 21")
 .groupby("constructorId")
 .agg(min_points = ("points", "min"), avg_points = ("points", "mean"))
 .query("avg_points >1"))
# Out:
#                min_points  avg_points
# constructorId
# 1                     0.0         3.0
# 2                     0.0         2.5
# 6                     8.0         9.0
# 9                     0.0         2.0
# 11                    0.0         1.5

# %% [markdown]
# <font size = "4">
#
# **Q6** Aggregate custom statistic
#
# <font size = "3">
#
# - Continue to use the DataFrame corresponding to the data in "results_cleaned.csv" (or read it in again).
#
# - We might consider it a "bad day" for an F1 driver if they finish outside the top ten (11th or worse). Write a function that takes in a Pandas Series and returns the number of entries $ > 10$.
#
# - Group by "driverId" and then aggregate the following statistics based on the "positionOrder" column: the average (mean) position and the number of finishes outside the top ten.
#
# - Use your custom function for this second statistic.
#
# - Merge the aggregated data back **into the original DataFrame**.

# %%
# your code here
df_results =  pd.read_csv("quiz_data/results_cleaned.csv")

def bad_days(col):
    days = 0
    for k in col:
        if k > 10:
            days = days + 1
    return days

df_aggregated = df_results.groupby(by = "driverId").agg(avg_position = ("positionOrder", "mean"),
                                                        outside_top_ten_finishes = ("positionOrder", bad_days))
                                  
df_results = pd.merge(left = df_results, right = df_aggregated, on = "driverId", how = "left")
display(df_results)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25655     25661    1086       825            210     20    13       16
# 25656     25662    1086       848              3     23    17       17
# 25657     25663    1086       849              3      6    19       18
# 25658     25664    1086       852            213     22    16       19
# 25659     25665    1086       822             51     77     8       20
#
#       positionText  positionOrder  points  laps         time  milliseconds  \
# 0                1              1    10.0    58  1:34:50.616     5690616.0
# 1                2              2     8.0    58       +5.478     5696094.0
# 2                3              3     6.0    58       +8.163     5698779.0
# 3                4              4     5.0    58      +17.181     5707797.0
# 4                5              5     4.0    58      +18.014     5708630.0
# ...            ...            ...     ...   ...          ...           ...
# 25655           16             16     0.0    69           \N           NaN
# 25656           17             17     0.0    69           \N           NaN
# 25657           18             18     0.0    69           \N           NaN
# 25658           19             19     0.0    68           \N           NaN
# 25659           20             20     0.0    65           \N           NaN
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId  avg_position  \
# 0             39    2       1:27.452         218.300         1      4.707641
# 1             41    3       1:27.739         217.586         1     10.722826
# 2             41    5       1:28.090         216.719         1      8.252427
# 3             58    7       1:28.603         215.464         1      8.409742
# 4             43    1       1:27.418         218.385         1     13.285714
# ...          ...  ...            ...             ...       ...           ...
# 25655         37   15       1:23.511         188.856        11     13.172932
# 25656         43   12       1:23.047         189.911        11     10.137255
# 25657         60    8       1:22.478         191.221        11     15.730769
# 25658         58   16       1:23.538         188.795        12     13.657143
# 25659         60   19       1:24.002         187.752       131      7.281250
#
#        outside_top_ten_finishes
# 0                            37
# 1                            83
# 2                            62
# 3                           116
# 4                            76
# ...                         ...
# 25655                        93
# 25656                        24
# 25657                        50
# 25658                        25
# 25659                        53
#
# [25660 rows x 20 columns]
